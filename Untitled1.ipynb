# %%
# !pip install graphviz

# %%
import graphviz

# %%
dot = graphviz.Digraph(comment='Justizpaket')

# %%
dot.node('AS', 'Antragsteller/HVMG')
dot.node('GA', 'Generalanwalt')
dot.node('DR', 'Deltarat')
dot.node('VSDR', 'Vorsitz. d. Deltarates')

dot.edges(['AS', 'GA'])

# %%
dot
